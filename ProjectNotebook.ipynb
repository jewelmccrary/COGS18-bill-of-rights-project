# %% [markdown]
# # Learning The Bill of Rights Through Code

# %% [markdown]
# My project allows users to test their AP US Government and Politics knowledge (specifically, of the first 10 amendments to the Constitution) through the use of a gov-themed Chatbot. Less fancy than the ones we demoed in class/ in A3, but I wanted to make something that used most of the things we've learned over the quarter while still being normally understandable! :)
#
# For the AP Gov exam, it's important for students to know the contents of each amendment, in addition to what "required" SCOTUS court cases are related to them. Students don't have to know the date that the Bill of Rights was ratified, but we're building some overachievers with this study tool! 🦅🦅🦅 Along those same lines, it was intentional that you have to write out all aspects of the amendmends and/or use specific wording to get your points. I'm trying to get these hypothetical kids to the 5, so they need to have a really clear understanding of the course content! The full amendment descriptions are included in the code file, even though they aren't used for anything within the code, just in case any of these kids want to look back at the original text to help them learn better.
#
# Even for people who have surpassed the age of high school government classes, it's always important to know what rights you have and how your government is supposed to work for the times when it doesn't... A beneficial learning tool for everyone.

# %% [markdown]
# ## Project Code
#
# For this project, the user needs to create a StudyingBillOfRights object before they can start studying. After initialization, users wanting to study specific amendments need to input the number of the amendment followed by a string description of their understanding. To study the Bill of Rights ratification date, users just need to input a date.
#
# **I have print statements around all of the code below because the default display in Jupyter notebooks will not do the stacked formatting that I coded otherwise. They are not necessary for the code to run, but I think it looks better with them included.

# %%
import module # your module.py file

# %%
from module import StudyingBillOfRights
try_1 = StudyingBillOfRights()

# %%
print(try_1.amend_description(1, "The first amendment protects the freedoms of speech, religion, press, assembly, and petition."))
# Out:
# 🦅 GovBot: Nice work! Madison is updating your stats.
# Score: 1

# %%
print(try_1.amend_description(1, "uhhh idk..."))
# Out:
# 🦅 GovBot: Nice try, but no. The eagle has placed you under academic review.
# Missing Concepts: speech, religion, press, assembly, petition
# Score: 1

# %%
print(try_1.amend_description(1, "i know speech and religion are in there somewhere..."))
# Out:
# 🦅 GovBot: Not quite. Alexander Hamilton is writing a strongly worded Federalist Paper about this.
# Missing Concepts: press, assembly, petition
# Score: 1

# %%
print(try_1.amend_description(4, "who searching this house!???"))
# Out:
# 🦅 GovBot: Incorrect. Remember, history has its eyes on you...
# Missing Concepts: no unreasonable search and seizure, search warrant, probable cause
# Score: 1

# %%
print(try_1.amend_description(4, "okay kidding, but i know this amendment says you need a search warrant."))
# Out:
# 🦅 GovBot: Not quite. Alexander Hamilton is writing a strongly worded Federalist Paper about this.
# Missing Concepts: no unreasonable search and seizure, probable cause
# Score: 1

# %%
print(try_1.amend_date(1776))
# Out:
# 🦅 GovBot: Not quite. Alexander Hamilton is writing a strongly worded Federalist Paper about this.
# Score: 1

# %%
print(try_1.amend_date(1791))
# Out:
# 🦅 GovBot: Correct! Alexander Hamilton nods approvingly.
# Score: 2

# %%
print(try_1.amend_scotus_cases(1, "new york times v. us"))
# Out:
# 🦅 GovBot: Incorrect. Time for a quick trip back to the notes.
# Missing Concepts: citizens united v. fec, wisconsin v. yoder, new york times vs. us, tinker v. des moines, engel v. vitale, schenck v. us
# Score: 2

# %%
print(try_1.amend_scotus_cases(1, "new york times v. us, citizens united v. fec, wisconsin v. yoder, new york times vs. us, tinker v. des moines, engel v. vitale, schenck v. us"))
# Out:
# 🦅 GovBot: Correct! Alexander Hamilton nods approvingly.
# Score: 3

# %%
print(try_1.amend_scotus_cases(2, "old mcdonald had a farm, e i e i ooooo"))
# Out:
# 🦅 GovBot: Not quite. This answer is helpless... but not hopeless.
# Missing Concepts: mcdonald v. chicago
# Score: 3

# %%
print(try_1.amend_scotus_cases(2, "mcdonald v. chicago"))
# Out:
# 🦅 GovBot: Nice work! Madison is updating your stats.
# Score: 4

# %%
print(try_1.amend_scotus_cases(6, "gideon v. wainwright"))
# Out:
# 🦅 GovBot: Outstanding! The eagle has awarded you one patriot point.
# Score: 5

# %%
StudyingBillOfRights?
# Out:
# Init signature: StudyingBillOfRights()
# Docstring:
# A study tool that quizzes users on the Bill of Rights.
#
# The class tracks a user's score and provides methods for
# reviewing amendment descriptions, ratification date,
# and important Supreme Court cases that relate to a specified amendment.
# Init docstring:
# Initialize a StudyingBillOfRights object.
#
# Creates a new study session and sets the user's score to zero.
#
# Returns
# -------
# None
#     This method does not return a value.
# File:           ~/module.py
# Type:           type
# Subclasses:

# %%
StudyingBillOfRights.amend_description?
# Out:
# Signature: StudyingBillOfRights.amend_description(self, num, desc)
# Docstring:
# Check whether a user's amendment description contains all required concepts.
#
# Compares the user's description against a list of required keywords
# associated with the specified amendment. If all required concepts are
# present, the user's score is increased by one and a random success
# message is returned. Otherwise, a random failure message and the
# missing concepts are returned.
#
# Parameters
# ----------
# num : int
#     Amendment number used to retrieve the required concepts.
# desc : str
#     User-provided description of the amendment.
#
# Returns
# -------
# str
#     A formatted message indicating whether the response was correct,
#     any missing concepts, and the current score.
# File:      ~/module.py
# Type:      function

# %% [markdown]
# #### Testing
#
# Run your tests. Sample code is provided below; you may need to edit this, depending upon how you've set up your tests.

# %%
import importlib
import tests

importlib.reload(tests)
# Out:
# <module 'tests' from '/home/jovyan/tests.py'>

# %%
# test it out
from module import StudyingBillOfRights
import unittest
import tests  # your tests.py file

unittest.main(tests.__name__, argv=[''], verbosity=2, exit=False)
# Out:
# test_amend_date_string_input (tests.TestStudyingBillOfRights.test_amend_date_string_input) ... ok
# test_amend_description_case_insensitive (tests.TestStudyingBillOfRights.test_amend_description_case_insensitive) ... ok
# test_amend_description_correct (tests.TestStudyingBillOfRights.test_amend_description_correct) ... ok
# test_amend_description_missing_concepts (tests.TestStudyingBillOfRights.test_amend_description_missing_concepts) ... ok
# test_amend_scotus_cases_partial (tests.TestStudyingBillOfRights.test_amend_scotus_cases_partial) ... ok
# test_score_accumulates (tests.TestStudyingBillOfRights.test_score_accumulates) ... ok
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.026s
#
# OK

# %% [markdown]
# #### GenAI Statement
#
# I used GenAI to help me complete this project! I came up with the project idea on my own, and then I fully wrote out all the code for my base project idea. After I was done with that, I explained to ChatGPT what I was trying to do and asked for opinions/potential fixes/improvements for the code I had already written. The original version had a lot of if/elif statements and things that were nested, so I knew that there were almost definitely ways to improve the structure of my project (refactoring) and have less hard coding. (ChatGPT came up with the idea of giving the GovBot a "personality" with different responses, which I thought was super funny. Guess who added most of the Hamilton jokes... 🫣) I also used ChatGPT to help with my docstrings, unit tests, debugging, and uploading to GitHub while also looking over those things myself.

# %% [markdown]
# #### Extra Credit (*optional*)
#
# Replace all of this text with a brief explanation (~3 sentences) of:
# 1. Coming into this class, I had zero previous Python knowledge! Had never written a line of code before, couldn't have even told you what any of these terms meant, etc. Everything I have conjured up across these different files was learned within the last 10 weeks!
# 2. Definitely not claiming that this is the most complex thing to come across your desk if people are building games with extra packages and whatnot, but the final version of this project with new improvements learned through ChatGPT definitely has more flare to it than the original version I had written! Even though we had learned about f-strings and the random module in class, I had never actually used either of these things in practice (or the new stacked formatting). I'm personally super happy with how this turned out and think it's cool/fun, so I just felt like sharing. :)
